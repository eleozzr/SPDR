# %%
import hnswlib
import scanpy as sc
import scanpy.external as sce
import pandas as pd
import os,csv

# %%
os.getcwd()
# Out:
# '/data3/testrstudio/lixiangjie_project/xinyi_xiangjie/SPDR/competing_methods'

# %%
import os,sys
import scanpy as sc
import numpy as np
import pandas as pd
mypath="/data3/testrstudio/lixiangjie_project/xinyi_xiangjie/SPDR"

if mypath not in sys.path:
    sys.path.append(mypath)
from model import spdr

from triplet_utils import generate_triplets
from preprocessing import normalize_scanpy

#root_dir="/Users/lixiangjie/Downloads/CarDEC-triplets/data/"
root_dir="/data3/testrstudio/lixiangjie_project/xinyi_xiangjie/SPDR/data/simulation"
adata_ori = sc.read(os.path.join(root_dir,"self_sim_complex.h5ad"))#self_sim1.h5ad
adata_ori.obs['batch']=adata_ori.obs['Batch']
adata_ori.obs['cells']=adata_ori.obs['Group']
adata0=adata_ori.copy()
BatchID="batch"

# %% [markdown]
# # UMAP

# %%
#adata_umap = adata.copy()
adata=adata_ori.copy()
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, n_top_genes=1000, subset = True)
#sc.pp.highly_variable_genes(adata, n_top_genes=2000, subset = True)
sc.tl.pca(adata)#,svd_solver='arpack'
adata_ori=adata.copy()
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.pl.umap(adata,color=['batch','cells'])
Y_umap=adata.obsm["X_umap"]
df0=pd.DataFrame(adata.obsm['X_umap'])
df0['celltype']=adata.obs.cells.astype(str).values
df0['BatchID']=adata.obs.batch.astype(str).values
df0.to_csv("./internal_results/simulation1_umap.tsv.gz",sep="\t",index=False)#compression='gzip'
# Out:
# 2022-08-02 15:24:28.680831: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-02 15:24:28.680867: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # IVIS

# %%
from ivis import Ivis

# %%
import ivis
ivis.__version__
# Out:
# '1.7.2'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
# %%time
adata=adata_ori.copy()
X = adata.obsm["X_pca"]
model = Ivis(k = 50, model = 'szubert', verbose=0)
model.fit(X)
adata.obsm["X_ivis"] = model.transform(X)
sc.pl.embedding(adata, basis = 'ivis', color = ["batch", "cells"])
Y_ivis=adata.obsm["X_ivis"]
df0=pd.DataFrame(adata.obsm['X_ivis'])
df0['celltype']=adata.obs.cells.astype(str).values
df0['BatchID']=adata.obs.batch.astype(str).values
df0.to_csv("./internal_results/simulation1_ivis.tsv.gz",sep="\t",index=False)#compression='gzip'
# Out:
# 2022-08-02 15:24:42.709874: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-08-02 15:24:42.709909: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-08-02 15:24:42.709927: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (localhost.localdomain): /proc/driver/nvidia/version does not exist
# 2022-08-02 15:24:42.710129: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %%time
adata=adata_ori.copy()
X = adata.obsm["X_pca"]
model = Ivis(k = 50, model = 'szubert', verbose=0)
model.fit(X)
adata.obsm["X_ivis"] = model.transform(X)
sc.pl.embedding(adata, basis = 'ivis', color = ["batch", "cells"])
Y_ivis=adata.obsm["X_ivis"]
df0=pd.DataFrame(adata.obsm['X_ivis'])
df0['celltype']=adata.obs.cells.astype(str).values
df0['BatchID']=adata.obs.batch.astype(str).values
df0.to_csv("./internal_results/simulation1_ivis.tsv.gz",sep="\t",index=False)#compression='gzip'
# Out:
# CPU times: user 2min 35s, sys: 51.5 s, total: 3min 27s
# Wall time: 58.1 s

# %% [markdown]
# # INSCT

# %%
from tnn.tnn import *

# %%
import tnn
tnn.__version__
# Out:
# '0.0.2'

# %%
import ivis
ivis.__version__
# Out:
# '1.7.2'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
adata_ori
# Out:
# AnnData object with n_obs × n_vars = 4000 × 1000
#     obs: 'Cell', 'Batch', 'Group', 'ExpLibSize', 'batch', 'cells'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
adata=adata_ori.copy()
model = TNN(k=15, distance='pn', batch_size=64, n_epochs_without_progress = 10, verbose = 0)
model.fit(X = adata, batch_name='batch')
adata.obsm["X_tnn"] = model.transform(X = adata)
sc.pl.embedding(adata, basis = 'tnn', color = ["batch", "cells"])
Y_insct=adata.obsm["X_tnn"]
df0=pd.DataFrame(adata.obsm['X_tnn'])
df0['celltype']=adata.obs.cells.astype(str).values
df0['BatchID']=adata.obs.batch.astype(str).values
df0.to_csv("./internal_results/simulation1_insct.tsv.gz",sep="\t",index=False)#compression='gzip'
# Out:
# version 0.0.2. 09:00, 12/01/2020
# Total cells for training:1155

# %% [markdown]
# # Trimap

# %%
import trimap
adata=adata_ori.copy()
X = adata.obsm["X_pca"]
embedding = trimap.TRIMAP(verbose=False).fit_transform(X)#
adata.obsm["X_trimap"] = embedding
sc.pl.embedding(adata, basis = 'trimap', color = ["batch", "cells"])
Y_trimap=adata.obsm["X_trimap"]
df0=pd.DataFrame(adata.obsm['X_trimap'])
df0['celltype']=adata.obs.cells.astype(str).values
df0['BatchID']=adata.obs.batch.astype(str).values
df0.to_csv("./internal_results/simulation1_trimap.tsv.gz",sep="\t",index=False)#compression='gzip'

# %% [markdown]
# # SPDR

# %% [markdown]
# - preprocessing

# %%
adata=adata0.copy()
adata=normalize_scanpy(adata=adata,
                       batch_key=BatchID,
                       n_high_var=1000,
                       hvg_by_batch=True,
                       normalize_samples=True,
                       target_sum=1e4,
                       log_normalize=True,
                       scale_features=True,
                       scale_features_by_batch=True,
                       do_pca=True,
                       do_tsne=True,
                       do_umap=True)

df0=pd.DataFrame(adata.obsm["X_pca"])
df0['celltype']=adata.obs.cells.astype(str).values
df0['BatchID']=adata.obs.batch.astype(str).values
df0.to_csv("./internal_results/simulation1_pca.tsv.gz",sep="\t",index=False)#compression='gzip'
# Out:
# /home/testrstudio2/anaconda3/envs/py37/lib/python3.7/site-packages/scanpy/preprocessing/_simple.py:843: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/testrstudio2/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,

# %%
#harmony_umap
#import scanpy.external as sce
#sce.pp.harmony_integrate(adata,BatchID)
#sc.pp.neighbors(adata,use_rep="X_pca_harmony")
#sc.tl.umap(adata)
#adata.obsm["X_harmony"]=adata.obsm['X_umap']
#sc.pl.scatter(adata, basis="harmony", color=["cells", "batch"])

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4000 × 1000
#     obs: 'Cell', 'Batch', 'Group', 'ExpLibSize', 'batch', 'cells', 'n_counts'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'log1p', 'hvg', 'pca', 'tsne', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %% [markdown]
# ## scale_by_batch=F

# %%
# %%time
adata.obs[BatchID]=adata.obs[BatchID].astype(str)
triplets, weights = generate_triplets(adata,
                      batch_key=BatchID,
                      dr="pca",
                      k_mnn=10,
                      k_mnn2=0,#20，20，20的结果比较好
                      k_nn=10,
                      k_out=10,
                      k_rand=5,
                      weight_adj=500.0,
                      approx=True,
                      verbose=True)
maprules = {v: i for i, v in enumerate(adata.obs_names)}
zz = np.array(list(map(lambda x: [maprules[i] for i in x], triplets)), dtype=np.int32)
Y = spdr(X=adata.obsm["X_pca"][:, :50].astype(np.float32),
         triplets=zz,
         n_iters=1000,
         weights=weights.astype(np.float32),
         Yinit=adata.obsm["X_tsne"][:, :2]*0.001,return_seq=True)# tsne are better than umap

adata.obsm['X_spdr'] = Y[list(Y)[-1]]
sc.pl.scatter(adata, basis="spdr", color=["cells", "batch"])
# Out:
# Step1: calculating MNNs pairs between all batches.....
# Processing datasets: (0, 1) = ('Batch1', 'Batch2')
# There are (2559) MNN pairs when processing (0, 1)=('Batch1', 'Batch2')
# Processing datasets: (0, 2) = ('Batch1', 'Batch3')
# There are (2963) MNN pairs when processing (0, 2)=('Batch1', 'Batch3')
# Processing datasets: (1, 2) = ('Batch2', 'Batch3')
# There are (3032) MNN pairs when processing (1, 2)=('Batch2', 'Batch3')
# 2894/4000 cells are defined as MNNS
# Finding neighbors globally for the all cells (4000)!!!
# Merge mnn and knn .....!!!!!!
# Step2:0.013397932052612305
# Step2:0.06867623329162598
# Step_get_nn_dict:0.9702205657958984
# Step_get_sig:1.0548813343048096
# Step_get_p_nn:1.118417501449585
# Step_get_out_triplets_random:24.11038827896118
# Step_get_p_nn:24.245582342147827
# Step_get_weight:25.02899932861328
# Step_get_random_triplet:29.25087332725525
# running TriMap on 4000 points with dimension 50
# running TriMap with sd
# ...

# %%
z=[np.hstack([v,np.ones(shape=(v.shape[0],1))*int(k)]) for k,v in Y.items()]
df0=pd.DataFrame(np.vstack(z),columns=["SPDR1","SPDR2","iter"])
df0['iter']=df0.iter.astype(int)
df0['celltype']=list(adata.obs.cells.astype(str).values)*len(Y)
df0['BatchID']=list(adata.obs.batch.astype(str).values)*len(Y)
df0.to_csv("./internal_results/simulation1_spdr_seq.tsv.gz",sep="\t",index=False)#compression='gzip'


df0=pd.DataFrame(Y[list(Y)[-1]])
df0['celltype']=adata.obs.cells.astype(str).values
df0['BatchID']=adata.obs.batch.astype(str).values
df0.to_csv("./internal_results/simulation1_spdr.tsv.gz",sep="\t",index=False)#compression='gzip'

# %% [markdown]
# # Trimap2

# %%
#trimap2
X = adata.obsm["X_pca"]
embedding = trimap.TRIMAP(verbose=False).fit_transform(X)#
adata.obsm["X_trimap"] = embedding
sc.pl.embedding(adata, basis = 'trimap',  color=["cells", "batch"])

df0=pd.DataFrame(adata.obsm["X_trimap"])
df0['celltype']=adata.obs.cells.astype(str).values
df0['BatchID']=adata.obs.batch.astype(str).values
df0.to_csv("./internal_results/simulation1_trimap2.tsv.gz",sep="\t",index=False)#compression='gzip'

# %%
#sc.pl.embedding(adata, basis = 'umap',  color=["cells", "batch"])

# %%
#sc.pl.embedding(adata, basis = 'tsne',  color=["cells", "batch"])

# %%
#sc.pl.embedding(adata, basis = 'pca',  color=["cells", "batch"])
